# %%
import numpy as np
import cv2
from PIL import Image
from IPython.display import display

# %%
img  =  cv2.imread("image.jpg")
img = cv2.resize(img,(500,300))
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x16AE8B2CD60>

# %%
greyscale_img =  cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
display(Image.fromarray(greyscale_img))
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x16AE8B4D070>

# %%
neg_img = cv2.bitwise_not(greyscale_img)
display(Image.fromarray(neg_img))
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x16AE8B4D280>

# %%
smooth_img = cv2.GaussianBlur(neg_img, (5,5), 0, 0)
display(Image.fromarray(smooth_img))
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x16AE8B4D250>

# %%
sketch_img = 255 - smooth_img
sketch = cv2.divide(greyscale_img, sketch_img, scale=250.0)
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=L size=500x300 at 0x16AE8B4D700>

# %%
rgb_img =  cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
display(Image.fromarray(rgb_img))
display(Image.fromarray(sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=500x300 at 0x16AE77EF5E0>
# <PIL.Image.Image image mode=L size=500x300 at 0x16AE8B4D7C0>
